# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.shape #Calculate number of rows and coloumns
# Out:
# (506, 14)

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.isnull().sum().sum() # Sum total number of null values in the data
# Out:
# 0

# %%
df.isnull().sum() # Sum value by column
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.quantile(1)
# Out:
# crim        88.9762
# zn         100.0000
# indus       27.7400
# chas         1.0000
# nox          0.8710
# rm           8.7800
# age        100.0000
# dis         12.1265
# rad         24.0000
# tax        711.0000
# ptratio     22.0000
# b          396.9000
# lstat       37.9700
# medv        50.0000
# Name: 1.0, dtype: float64

# %%
df['medv'].mean()
# Out:
# 22.532806324110677

# %%
df['lstat'].mean()
# Out:
# 12.653063241106722

# %%
np.round(df['medv'].mean(),2) # Round function in 2
# Out:
# 22.53

# %%
df['medv'].median() # Median directly from the function
# Out:
# 21.2

# %%
df['medv'].quantile(0.50) # Median of the data through qunatile
# Out:
# 21.2

# %%
df['medv'].mode() # Mode of the data
# Out:
# 0    50.0
# dtype: float64

# %%
# Flag variable are the variables which are binary in nature

df['medv_flag']  = np.where(df['medv'] <= df['medv'].mean(),0,1)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv  medv_flag
# 0  396.90   4.98  24.0          1
# 1  396.90   9.14  21.6          0
# 2  392.83   4.03  34.7          1
# 3  394.63   2.94  33.4          1
# 4  396.90   5.33  36.2          1

# %%
tmp=df.groupby('medv_flag').describe()
tmp
# Out:
#             crim                                                          \
#            count      mean        std      min     25%      50%      75%
# medv_flag
# 0          297.0  5.563153  10.668584  0.01096  0.1396  0.84054  7.67202
# 1          209.0  0.842998   2.125546  0.00632  0.0536  0.10469  0.46296
#
#                        zn             ...  lstat          medv             \
#                max  count       mean  ...    75%    max  count       mean
# medv_flag                             ...
# 0          88.9762  297.0   4.587542  ...  19.88  37.97  297.0  16.870370
# 1          14.4383  209.0  20.992823  ...   9.16  29.55  209.0  30.579426
#
#
#                 std   min   25%   50%   75%   max
# medv_flag
# 0          4.233162   5.0  13.9  18.0  20.3  22.5
# 1          8.308060  22.6  24.0  27.9  34.6  50.0
#
# [2 rows x 112 columns]

# %%
df.corr()
# Out:
#                crim        zn     indus      chas       nox        rm  \
# crim       1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# zn        -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# indus      0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# chas      -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# nox        0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# rm        -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# age        0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# dis       -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# rad        0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# tax        0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# ptratio    0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# b         -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# ...

# %%
plt.matshow(df.corr())

# %%
df.hist() # Use to remove hefty text

# %%
df['crim'].hist(color='orange')
plt.title('My first Box plot')
plt.ylabel('Frequency')
plt.xlabel('crime rate')
plt.show()

# %%
# Boxplot 
# First grab the data fram and the select the coloumn 

df.boxplot('medv',color = 'purple')

plt.ylabel('Median House Value ($)')
plt.show()

# The box plot shows minimum, 25%, Median, 75%, and Maximum value.The two whiskers are minimum and maximum values
# Points above the whiskers are outliers

# %%
df.boxplot('crim')
plt.show()

# %%
df['medv'].plot.density() # Syntacx for univariate density plot is different then the box plot
plt.show()

# %%
df['crim'].plot.density() # Density(Probability density function alwaya positive) plot of one of the indepenedent variable 
plt.xlim([0,np.max(df['crim'])])
plt.show()

# %%
df.boxplot()
plt.show()
